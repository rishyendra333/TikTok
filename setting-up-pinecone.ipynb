# %%
# %pip install pinecone
# %pip install sentence_transformers
# Out:
# Requirement already satisfied: pinecone in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (4.0.0)
# Requirement already satisfied: certifi>=2019.11.17 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from pinecone) (2023.7.22)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from pinecone) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from pinecone) (4.11.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from pinecone) (1.26.16)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence_transformers in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.41.2)
# Requirement already satisfied: tqdm in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (2.2.2)
# Requirement already satisfied: numpy in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.23.4)
# Requirement already satisfied: Pillow in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (9.4.0)
# Requirement already satisfied: filelock in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2024.6.0)
# Requirement already satisfied: packaging>=20.9 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (6.0)
# Requirement already satisfied: requests in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.15.1->sentence_transformers) (4.11.0)
# Requirement already satisfied: sympy in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (2022.7.9)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.34.0->sentence_transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.15.1->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence_transformers) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ffmpeg
import io
import numpy as np
import tempfile
from PIL import Image
from sentence_transformers import models, SentenceTransformer
# Out:
# /Users/kaushikmedamanuri/anaconda3/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
# Initialize the CLIP model
img_model = SentenceTransformer(modules=[models.CLIPModel()])

# %%
def get_scaled_size(width, height):
    target_width = 224
    w_percent = (target_width / float(width))
    h_size = int((float(height) * float(w_percent)))
    return target_width, h_size

# %%
def to_byte_array(image):
    """Converts a numpy array image to a byte array"""
    img = Image.fromarray(image)
    with io.BytesIO() as output:
        img.save(output, format="PNG")
        return output.getvalue()

# %%
def get_frames(video_path):
    with tempfile.NamedTemporaryFile() as f:
        # Read the video file
        with open(video_path, "rb") as video_file:
            video_bytes = video_file.read()
        
        f.write(video_bytes)
        f.flush()
        
        probe = ffmpeg.probe(f.name, threads=1)
        video_info = next(s for s in probe['streams'] if s['codec_type'] == 'video')
        width, height = get_scaled_size(int(video_info['width']), int(video_info['height']))

        out, _ = (
            ffmpeg
            .input(f.name, threads=1)
            .filter('scale', width, height)
            .output('pipe:', format='rawvideo', pix_fmt='rgb24')
            .run(capture_stdout=True, capture_stderr=True)
        )
        frames = (
            np
            .frombuffer(out, np.uint8)
            .reshape([-1, height, width, 3])
        )
        
        indexes = np.random.randint(frames.shape[0], size=10)
        return [to_byte_array(frame) for frame in frames[indexes, :]]

# %%
def get_embeddings(frames):
    images = [Image.open(io.BytesIO(frame)) for frame in frames]
    vectors = img_model.encode(images)
    return vectors

# %%
# Path to your video file
video_path = "video1881698513.mp4"

# Get frames from the video
frames = get_frames(video_path)

# Get embeddings for the frames
embeddings = get_embeddings(frames)

# Print the dimensions of the embeddings
embedding_dimension = embeddings[0].shape[0]
print(f"The dimension of the embeddings is: {embedding_dimension}")
# Out:
# The dimension of the embeddings is: 512

# %% [markdown]
# # Don't rerun the cell below. It will restart the database

# %%
from pinecone import Pinecone, ServerlessSpec

pc = Pinecone(api_key='44a257b1-5d26-4544-9825-d51ddaaa13e3')

index_name = "tiktok-hackathon"
dimension = 512  # Dimension of CLIP embeddings

if index_name not in pc.list_indexes().names():
  pc.create_index(
      name=index_name,
      dimension=dimension,
      metric="cosine",
      spec=ServerlessSpec(
          cloud='aws',
          region='us-east-1'
      )
  )

# %%
vectors_with_metadata = [
    {
        "id": str(i),
        "values": embedding.tolist(),  # Convert embedding to list if it's a numpy array
    }
    for i, embedding in enumerate(embeddings)
]

# %%
index = pc.Index(index_name)
index.upsert(vectors=vectors_with_metadata, namespace="video_embeddings")
# Out:
# {'upserted_count': 10}

# %% [markdown]
# # Searching from pinecone

# %%
test_vect = img_model.encode('Triangles are very cool objects and a presentation on them is interesting.')

# %%
query_results = index.query(
    namespace="video_embeddings",
    vector=test_vect.tolist(),
    top_k=1,
    include_values=True,
    include_metadata=True
)

# Print the query results
print(query_results)
# Out:
# {'matches': [{'id': '7',
#               'score': 0.279680938,
#               'values': [0.147639453,
#                          -0.103531122,
#                          -0.122731723,
#                          -0.0790869892,
#                          -0.658142209,
#                          -0.24769868,
#                          -0.0634254515,
#                          -0.350750536,
#                          0.508789659,
#                          -0.155952871,
#                          0.068514213,
#                          0.322130144,
#                          0.398772657,
#                          0.193546489,
#                          -0.118484773,
#                          0.0567304343,
#                          -0.0542633832,
#                          0.115617201,
#                          0.0644490123,
#                          0.181323558,
#                          0.465192318,
#                          0.026368618,
#                          0.00809099525,
#                          0.224028051,
#                          -0.122077093,
#                          0.391799092,
#                          0.177749678,
#                          -0.0610275865,
#                          -0.237818033,
#                          -0.31265685,
#                          0.278717577,
#                          -0.506529272,
#                          0.331871867,
#                          0.138544828,
#                          0.747591,
#                          -0.0305431187,
#                          0.0189177096,
#                          0.653720677,
#                          0.27502811,
#                          -2.31097984,
#                          -0.441951334,
#                          -0.477425545,
#                          -0.37996608,
#                          -0.439573169,
#                          -0.242525429,
#                          0.0736973286,
#                          -0.102082387,
#                          0.113703132,
#                          -0.0768180639,
#                          -0.155122548,
#                          0.30414781,
#                          0.112948075,
#                          -0.330623269,
#                          -0.152915925,
#                          -0.562905967,
#                          -0.328875,
#                          -0.422928572,
#                          0.142814472,
#                          -0.161408067,
#                          0.0145738274,
#                          0.609855771,
#                          -0.0132174417,
#                          0.331527829,
#                          -0.170311257,
#                          -0.539980412,
#                          -0.357588023,
#                          -0.328416198,
#                          0.469008356,
#                          -0.529298782,
#                          -0.595027924,
#                          0.107789375,
#                          0.369968235,
#                          0.0825460553,
#                          -0.0620476231,
#                          -0.137230709,
#                          -0.112626515,
#                          0.104093492,
#                          -0.0699537247,
#                          -0.186021745,
#                          -0.341582358,
#                          -0.285624772,
#                          -0.155815125,
#                          -0.203790575,
#                          0.10306745,
#                          -0.0906409323,
#                          -0.365772277,
#                          2.04301167,
#                          0.0209850371,
#                          0.379140586,
#                          -0.0781207532,
#                          0.462834686,
#                          0.205499008,
#                          -4.80327892,
#                          0.0769187957,
#                          -0.0225608647,
#                          0.0854327,
#                          0.296333015,
#                          -0.462071568,
#                          -0.0721893609,
#                          -0.0390241146,
#                          -0.373021454,
#                          -0.00368129462,
#                          -0.383301258,
#                          -0.495001346,
#                          -0.486509144,
#                          0.146933466,
#                          -2.90944552,
#                          0.180087,
#                          -0.538139403,
#                          -0.0304865837,
#                          0.285597086,
#                          -0.229619935,
#                          0.178462565,
#                          0.197046816,
#                          -0.0127986073,
#                          0.230965599,
